# %%
# !pip install matplotlib

# %%
import matplotlib

# %%
from numpy import*
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
t=linspace(-10,10,1000)
N=len(t)
A=1
shift=0
u=zeros(N)
for i in range(0,N):
    if t[i]>=-shift:
        u[i]=A
plt.plot(t,u)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, +10, 0.03)
y = 1 / (1 + np.exp(-x))

plt.plot(x, y)
plt.show()

# %%
from math import exp
from matplotlib import pyplot

def tanh(x):
    return (exp(x) - exp(-x)) / (exp(x) + exp(-x))

inputs = [x for x in range(-10, 10)]

outputs = [tanh(x) for x in inputs]

pyplot.plot(inputs, outputs)
pyplot.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.05)
y = np.maximum(0.0, x)

plt.plot(x, y)
plt.show()

# %%
import numpy as np

# %%
def ELU(x,a):
    if x<0:
        return a*(np.exp(x)-1)
    else:
        return x

# %%
ELU(-0.5,0.2)
# Out:
# -0.07869386805747332

# %%
ELU(7,0.2)
# Out:
# 7

# %%
xSeries = np.linspace(-10,10,101)

# %%
outputSeries5 = [ELU(eachX,0.02) for eachX in xSeries]

# %%
outputSeries6 = [ELU(eachX,1) for eachX in xSeries]

# %%
outputSeries7 = [ELU(eachX,2) for eachX in xSeries]

# %%
outputSeries8 = [ELU(eachX,5) for eachX in xSeries]

# %%
plt.plot(xSeries, outputSeries5, xSeries, outputSeries6, xSeries, outputSeries7, xSeries, outputSeries8, linestyle = '--', linewidth = 5)

# %%
import numpy as np
import matplotlib.pyplot as plt
λ = 1.0507
α = 1.6732

def SELU(x):
    if x > 0:
        return λ*x
    return λ*α*(np.exp(x) - 1)

x = np.linspace(-5.0, 5.0)
result = []
for i in x:
    result.append(SELU(i))

plt.plot(x, result)
plt.title("SELU activation function")
plt.xlabel("Input")
plt.ylabel("Output")
# Out:
# Text(0, 0.5, 'Output')
